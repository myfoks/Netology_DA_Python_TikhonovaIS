# %% [markdown]
# ## Домашнее задание по блоку 11.03.2021. Библиотека Pandas
# ### Тихонова Инна

# %%
import pandas as pd
from IPython.display import display

# %% [markdown]
# **Задание 1**
#
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите, какому фильму было выставлено больше всего оценок 5.0.

# %%
ratings = pd.read_csv("ratings.dat", sep='::', engine='python',
                     names = ['UserID', 'MovieID', 'Rating', 'Timestamp'])
ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
movies = pd.read_csv("movies.dat", sep='::', engine='python',
                    names = ['MovieID', 'Title', 'Genres'])
movies.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
movies.merge(

    (ratings
     .query('Rating == 5')
     .groupby('MovieID')
     .count()
     .sort_values(by='Rating', ascending=False)
     .head(1)
    ),
    
    on='MovieID'
    
)[['MovieID', 'Title', 'Genres']]
# Out:
#    MovieID                   Title        Genres
# 0     2858  American Beauty (1999)  Comedy|Drama

# %% [markdown]
# **Задание 2**
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
baltic = ['Lithuania', 'Latvia', 'Estonia']
cats = [4, 12, 21]

(power
 .query('country in @baltic and category in @cats and year >= 2005 and year <= 2010 and quantity > 0')
 ['quantity'].sum()
)
# Out:
# 240580.0

# %% [markdown]
# **Задание 3**
#
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц:
#  * https://fortrader.org/quotes
#  * https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
page_url = 'https://fortrader.org/quotes'
dfs = pd.read_html(page_url, encoding='utf-8')

# %%
for df in dfs:
    display(df)
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  88.00       1.34          1.54        NaN
# 1       USDRUB Курс рубля к доллару  73.92       1.06          1.46        NaN
#                               Название    Цена  Изменение  Изменение(%)  \
# 0       Нефть Brent Курс нефти сегодня   67.59      -0.88         -1.29
# 1          Нефть WTI Цены на нефть WTI   64.02      -0.88         -1.36
# 2  Природный газ Цена на природный газ    2.52      -0.04         -1.64
# 3                                 Кофе  133.10      -1.40         -1.04
# 4                             Кукуруза  555.40       2.00          0.36
# 5                                  Соя  402.30      -3.40         -0.84
# 6                               Хлопок   86.88      -0.04         -0.05
#
#    Обновлено
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# ...
